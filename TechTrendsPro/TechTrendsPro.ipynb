# %%
pip install mysql.connector-python
# Out:
# Requirement already satisfied: mysql.connector-python in c:\users\user\anaconda3\lib\site-packages (9.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
connection = mysql.connector.connect(host = "localhost",
                                     user = "root" ,
                                     password = "Emmanuella1#" ,
                                     db = "techtrendpro")

# %%
connection

# %%
techtrendpro_tables = pd.read_sql_query('SHOW TABLES', connection)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21088\4168578782.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   techtrendpro_tables = pd.read_sql_query('SHOW TABLES', connection)

# %%
techtrendpro_tables
# Out:
#   Tables_in_techtrendpro
# 0          feedback_data
# 1           product_data
# 2             sales_data

# %%
feedback = pd.read_sql_query("SELECT * FROM feedback_data", connection)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21088\177151503.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   feedback = pd.read_sql_query("SELECT * FROM feedback_data", connection)

# %%
feedback.head()
# Out:
#    Feedback ID  Product ID return date      Return Reason  \
# 0            1         124  2023-06-04    Changed my mind
# 1            2         160  2022-12-22   Not as described
# 2            3         187  2023-03-10  Defective product
# 3            4          37  2023-02-10    Changed my mind
# 4            5         178  2022-12-15   Not as described
#
#                                    Customer Feedback
# 0  The product I received didn't match the descri...
# 1  The product I received didn't match the descri...
# 2  The product I received was defective. It didn'...
# 3  I received the wrong item. It's not what I ord...
# 4  The quality of the product is disappointing. I...

# %%
feedback_describe = pd.read_sql_query("DESCRIBE feedback_data", connection)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21088\289185234.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   feedback_describe = pd.read_sql_query("DESCRIBE feedback_data", connection)

# %%
feedback_describe
# Out:
#                Field  Type Null Key Default Extra
# 0        Feedback ID   int  YES        None
# 1         Product ID   int  YES        None
# 2        return date  date  YES        None
# 3      Return Reason  text  YES        None
# 4  Customer Feedback  text  YES        None

# %%
product = pd.read_sql_query("SELECT * FROM product_data", connection)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21088\4235847436.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product = pd.read_sql_query("SELECT * FROM product_data", connection)

# %%
product.head()
# Out:
#    Product ID Product Category    Product Attributes
# 0           1      Accessories   Resolution (pixels)
# 1           2      Accessories         Compatibility
# 2           3      Accessories              Material
# 3           4      Smartphones   Camera Quality (MP)
# 4           5      Smartphones  Battery Life (hours)

# %%
sales = pd.read_sql_query("SELECT * FROM sales_data", connection)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21088\4176987875.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales = pd.read_sql_query("SELECT * FROM sales_data", connection)

# %%
sales.head()
# Out:
#    Sale ID  Product ID  sales date  Sales Volume  Revenue Generated
# 0        1          25  2023-08-10             6             448.40
# 1        2         169  2023-04-21            41             355.71
# 2        3         111  2022-10-02            40             445.44
# 3        4          91  2022-10-29            66             734.27
# 4        5         109  2023-03-17            51             307.70

# %%
product_describe = pd.read_sql_query("DESCRIBE product_data", connection)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21088\861316058.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_describe = pd.read_sql_query("DESCRIBE product_data", connection)

# %%
product_describe
# Out:
#                 Field  Type Null Key Default Extra
# 0          Product ID   int  YES        None
# 1    Product Category  text  YES        None
# 2  Product Attributes  text  YES        None

# %%
sales_describe = pd.read_sql_query("DESCRIBE sales_data", connection)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21088\2260262406.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales_describe = pd.read_sql_query("DESCRIBE sales_data", connection)

# %%
sales_describe
# Out:
#                Field    Type Null Key Default Extra
# 0            Sale ID     int  YES        None
# 1         Product ID     int  YES        None
# 2         sales date    date  YES        None
# 3       Sales Volume     int  YES        None
# 4  Revenue Generated  double  YES        None

# %% [markdown]
# ## Descriptive Analysis

# %%
feedback.describe(include = 'all')
# Out:
#         Feedback ID   Product ID return date        Return Reason  \
# count   1500.000000  1500.000000        1500                 1500
# unique          NaN          NaN         357                    5
# top             NaN          NaN  2022-11-15  Wrong item received
# freq            NaN          NaN          12                  335
# mean     750.500000   102.080667         NaN                  NaN
# std      433.157015    58.738389         NaN                  NaN
# min        1.000000     1.000000         NaN                  NaN
# 25%      375.750000    48.000000         NaN                  NaN
# 50%      750.500000   104.000000         NaN                  NaN
# 75%     1125.250000   155.000000         NaN                  NaN
# max     1500.000000   200.000000         NaN                  NaN
#
#                                         Customer Feedback
# count                                                1500
# unique                                                 10
# top     I received the wrong item. It's not what I ord...
# freq                                                  175
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
product.describe(include = 'all')
# Out:
#         Product ID Product Category Product Attributes
# count   200.000000              200                200
# unique         NaN                3                 17
# top            NaN      Accessories      Color Options
# freq           NaN               74                 36
# mean    100.500000              NaN                NaN
# std      57.879185              NaN                NaN
# min       1.000000              NaN                NaN
# 25%      50.750000              NaN                NaN
# 50%     100.500000              NaN                NaN
# 75%     150.250000              NaN                NaN
# max     200.000000              NaN                NaN

# %%
sales.describe(include = 'all')
# Out:
#             Sale ID   Product ID  sales date  Sales Volume  Revenue Generated
# count   2000.000000  2000.000000        2000   2000.000000        2000.000000
# unique          NaN          NaN         363           NaN                NaN
# top             NaN          NaN  2023-02-20           NaN                NaN
# freq            NaN          NaN          12           NaN                NaN
# mean    1000.500000   102.109500         NaN     51.725000         519.684015
# std      577.494589    57.415519         NaN     28.627629         273.633332
# min        1.000000     1.000000         NaN      1.000000          50.090000
# 25%      500.750000    54.000000         NaN     27.000000         283.342500
# 50%     1000.500000   104.000000         NaN     52.000000         518.560000
# 75%     1500.250000   153.000000         NaN     76.000000         753.097500
# max     2000.000000   200.000000         NaN    100.000000         999.630000

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
sales_product_data = pd.merge(sales, product, on = 'Product ID') 

full_data = pd.merge(feedback, sales_product_data, on = 'Product ID')

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15121 entries, 0 to 15120
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Feedback ID         15121 non-null  int64
#  1   Product ID          15121 non-null  int64
#  2   return date         15121 non-null  object
#  3   Return Reason       15121 non-null  object
#  4   Customer Feedback   15121 non-null  object
#  5   Sale ID             15121 non-null  int64
#  6   sales date          15121 non-null  object
#  7   Sales Volume        15121 non-null  int64
#  8   Revenue Generated   15121 non-null  float64
#  9   Product Category    15121 non-null  object
#  10  Product Attributes  15121 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.3+ MB

# %%
full_data['sales date'] = pd.to_datetime(full_data['sales date'])

full_data['return date'] = pd.to_datetime(full_data['return date'])

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15121 entries, 0 to 15120
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Feedback ID         15121 non-null  int64
#  1   Product ID          15121 non-null  int64
#  2   return date         15121 non-null  datetime64[ns]
#  3   Return Reason       15121 non-null  object
#  4   Customer Feedback   15121 non-null  object
#  5   Sale ID             15121 non-null  int64
#  6   sales date          15121 non-null  datetime64[ns]
#  7   Sales Volume        15121 non-null  int64
#  8   Revenue Generated   15121 non-null  float64
#  9   Product Category    15121 non-null  object
#  10  Product Attributes  15121 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Univarate Analysis ---  To identify trends in the dataset
#
# Since the analysis is to establish and find relationship between product quality to return rates
#
# we will be looking at strategic columns that are focused on the aim of the project
# 1. sales volume
# 2. revenue generated
# 3. return rates
# 4. product category

# %%
# Univarate analysis for sales volume
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10))

sns.histplot(full_data['Sales Volume'], kde = True, ax=axes[0,0])
axes[0,0].set_title("Distribution of Sales volume")
axes[0,0].set_xlabel("Sales volume")
axes[0,0].set_ylabel("Frequency")

# Univarate analysis for revenue generated
sns.histplot(full_data['Revenue Generated'], kde = True, ax=axes[0,1])
axes[0,1].set_title("Distribution of Revenue Generated")
axes[0,1].set_xlabel("Revenue Generated")
axes[0,1].set_ylabel("Frequency")

# Univarate analysis for return reason
return_reason_counts = full_data['Return Reason'].value_counts()

return_reason_counts.plot(kind = 'bar',  ax=axes[1,0])
axes[1,0].set_title("Distribution of Return Reasons")
axes[1,0].set_xlabel("Return reasons")
axes[1,0].set_ylabel("Count")
axes[1,0].tick_params(axis = 'x', rotation = 45)

# univarate analysis for product category
product_category_counts = full_data['Product Category'].value_counts()

product_category_counts.plot(kind = 'bar',  ax=axes[1,1])
axes[1,1].set_title("Distribution of Product Category")
axes[1,1].set_xlabel("Product Category")
axes[1,1].set_ylabel("Count")
axes[1,1].tick_params(axis = 'x', rotation = 360)

fig.suptitle('Univarate analysis for Selected Columns', fontsize = 16)
plt.tight_layout(rect=[0,0,1,0.96])
plt.show()

# %% [markdown]
# ## Bivarate Analysis -- To check the relationship between return reason and each product category

# %%
plt.figure(figsize=(12,6))
sns.countplot(y= 'Return Reason', hue = "Product Category", data = full_data)
plt.title("Return Reasons by Product Category")
plt.xlabel("Count of returns")
plt.ylabel("Return Reason")
plt.show()

# %% [markdown]
# ## Deep dive into Product Quality and Return Rates

# %%
unique_feedback = full_data['Customer Feedback'].unique().tolist()
print(unique_feedback)
# Out:
# ["The product I received didn't match the description. It was misleading.", "The product I received was defective. It didn't work properly.", "I received the wrong item. It's not what I ordered.", "The quality of the product is disappointing. It's not worth the price.", 'I expected something different based on the description. Disappointed.', "I'm not satisfied with the quality of this product. It's subpar.", "Unfortunately, I decided I didn't need this product anymore.", 'I changed my mind after purchasing the product. Can I return it for a refund?', "This product had a defect, and I'm not satisfied with it.", "This is not what I ordered, and I'd like to get the correct item."]

# %%
unique_reasons = full_data['Return Reason'].unique().tolist()
print(unique_reasons)
# Out:
# ['Changed my mind', 'Not as described', 'Defective product', 'Wrong item received', 'Poor quality']

# %%
quality_related_terms = ['poor quality', 'not as described', 'defective', 'disappointing', 'poor']

full_data['Quality Issue'] = full_data['Customer Feedback'].apply(
    lambda x: any(term in x.lower() for term in quality_related_terms)
)

quality_issue_returns = full_data['Quality Issue'].value_counts()

plt.figure(figsize=(12,6))
sns.countplot(x= 'Product Category', hue = "Quality Issue", data = full_data)
plt.title("quality issues by category")
plt.xlabel("Product category")
plt.ylabel("count")
plt.show()

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(full_data['Product Category'], full_data['Quality Issue'])
chi2,p,dof,expected = chi2_contingency(contingency_table)

chi2_test_results = {
    'Chi-Square Statistic': chi2,
    'p-value':p,
    'Degrees of Freedom':dof,
    'Expected Frequencies':expected
}

# %%
quality_issue_returns
# Out:
# Quality Issue
# False    12404
# True      2717
# Name: count, dtype: int64

# %%
chi2_test_results
# Out:
# {'Chi-Square Statistic': 6.5587129862987865,
#  'p-value': 0.03765247864083011,
#  'Degrees of Freedom': 2,
#  'Expected Frequencies': array([[4543.73097017,  995.26902983],
#         [3620.05502282,  792.94497718],
#         [4240.21400701,  928.78599299]])}

# %%
expected_df = pd.DataFrame(expected,
                           index=contingency_table.index,
                           columns=contingency_table.columns)
fig, ax = plt.subplots(1,2, figsize=(12,6))
sns.heatmap(contingency_table, annot = True, cmap = 'viridis', ax=ax[0])
ax[0].set_title('Observed Frequencies')

sns.heatmap(expected_df, annot = True, cmap = 'viridis', ax=ax[1])
ax[1].set_title('Expected Frequencies')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights
#
# - Quality-Related Returns Vary Across Categories:
# A significant proportion of returns are linked to quality issues, especially in certain product categories.
# The chi-square test indicated a statistically significant relationship between product categories and quality issues.
#
# - Specific Categories with Higher Quality Issues:
# Among the product categories, some show a higher prevalence of quality-related feedback. These categories warrant closer inspection and targeted improvements.
#
# - Customer Feedback as a Quality Indicator:
# Customer feedback frequently mentions quality issues like 'defective products' or 'poor quality', highlighting the importance of addressing these concerns.
#
# ## Recommendations
# - Enhanced Quality Control for Targeted Categories:
# TechTrend Pro should implement stricter quality control measures, especially for the product categories with a higher incidence of quality-related returns. This could involve more rigorous testing and inspection processes.
#
# - Review and Strengthen Supplier Relationships:
# Analyze and review supplier performance. For suppliers consistently linked to quality issues, consider renegotiation of terms, additional quality checks, or seeking alternative suppliers.
#
# - Leverage Customer Feedback for Product Improvements:
# Utilize the insights from customer feedback to inform product development. Identify common complaints and address these in future product designs or updates.
#
# - Enhance Customer Education and Support:
# Some returns may be due to misunderstandings about product use. Providing better educational materials and proactive customer support could reduce such returns.
#
# - Regular Data Analysis for Continuous Improvement:
# Continue to analyze sales, feedback, and return data regularly to identify emerging trends or new issues, allowing for timely corrective actions.
#
# - Invest in Predictive Analytics:
# Implement predictive analytics to identify potential quality issues before products are shipped. This could help in proactively addressing problems and reducing future returns.
#
# ## Conclusion
# By focusing on these areas, TechTrend Pro can potentially reduce return rates, leading to increased customer satisfaction and reduced operational costs associated with handling returns. The key is a combination of proactive quality management, continuous data monitoring, and leveraging customer feedback for ongoing improvements.
